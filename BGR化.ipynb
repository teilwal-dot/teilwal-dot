# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
 
im = cv2.imread('/content/drive/MyDrive/特別研究/frame_mp4/frame/bar/bar_001.jpg')
print(im)
# Out:
# [[[177 158 155]
#   [177 158 155]
#   [177 158 155]
#   ...
#   [118 103 101]
#   [118 103 101]
#   [118 103 101]]
#
#  [[177 158 155]
#   [177 158 155]
#   [177 158 155]
#   ...
#   [118 103 101]
#   [118 103 101]
#   [118 103 101]]
#
#  [[177 158 155]
#   [177 158 155]
#   [177 158 155]
#   ...
#   [118 103 101]
#   [118 103 101]
#   [118 103 101]]
#
#  ...
#
#  [[ 83  47 153]
#   [ 83  47 153]
#   [ 83  47 153]
#   ...
#   [ 60  27 112]
#   [ 60  27 112]
#   [ 60  27 112]]
#
#  [[ 85  47 153]
#   [ 84  46 152]
#   [ 85  47 153]
#   ...
#   [ 60  27 112]
#   [ 60  27 112]
#   [ 60  27 112]]
#
#  [[ 85  47 153]
#   [ 85  47 153]
#   [ 86  48 154]
#   ...
#   [ 61  28 113]
#   [ 61  28 113]
#   [ 61  28 113]]]

# %%
# 1セル1文でも全部まとめても可
import cv2
from google.colab.patches import cv2_imshow

cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FDDAA2AA8D0>

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(30, 30), dpi=500)
plt.axis("off")
plt.imshow(im)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

plt.imsave("/content/drive/MyDrive/特別研究/frame_mp4/frame/bar/sampleBGR.jpg",im)
