# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers==4.5.0
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 37.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 43.5 MB/s
# ...

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"

# %%
# b) Load model & tokenizer
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/496M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/79.0 [00:00<?, ?B/s]

# %%
with open('/content/drive/MyDrive/特別研究/context.txt') as f:
    s = f.read()

print(s)
# Out:
# green light. blurry. yellow light. blurry person. blurry person. blurry person. blurry. blurry. blurry. blurry. blurry. blurry. blurry. blurry person. blurry. blurry. blurry. blurry. blurry. blurry. blurry. dark. blurry. blurry. blurry. blurry. blurry. blurry. blurry. dark. blurry. blurry. blurry. dark. blurry. blurry. blurry.

# %%
# a) Get predictions
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
     'question' : 'What kind of hairstyle does the person have?',
   #'question' : 'What is the person doing?',
   #'question' : 'What does a person wear?',
   #'question' : 'What do you see in the video?',
   #'question' : 'Where was the video shot?',
   #'question' : 'When was the video taken?',
   #'question' : 'How many people are there?',
     'context' : s
}
res = nlp(QA_input)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/question_answering.py:315: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   fw_args = {k: torch.tensor(v, device=self.device) for (k, v) in fw_args.items()}

# %%
res
# Out:
# {'answer': 'blurry', 'end': 41, 'score': 0.02283710055053234, 'start': 35}

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"

# a) Get predictions
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
    'question': 'What is the person doing?',
    'context': 'red table. green bottle.man sitting.red table.brown hair.dark glasses.red table.clear bottle.blue bottle.woman sitting.red table.blue wall.clear glass.black shirt.'\
    +'black shirt.blue wall..brown woman.small hands.clear glass.seated man.bald head.black glass.red table.plastic bottle.blue wall.blue wall.black bottle.silver ring.black glass.'\
    + 'white man.black label.red table.woman sitting.black table.green label.red hat.black bottle.'\
}
res = nlp(QA_input)

# b) Load model & tokenizer
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
